# %% [markdown]
# ## Sushma Rani Reddy Aleti

# %% [markdown]
# Twitter accounts:
#     - Virat Kohli(@imVkohli)
#     - Sunil Chhetri(@chetrisunil11)
#     - Arijit Singh(@ARIJIT__SINGH)

# %%
# this cell is to retrieve information from Twitter and store in pickle file

import pickle
import tweepy
from twitter_keys import consumer_key, consumer_secret, access_token, access_secret

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token( access_token, access_secret)

api = tweepy.API(auth)

kohli_tweets = api.user_timeline('@imVkohli')
chetri_tweets = api.user_timeline('@chetrisunil11')
arijit_tweets = api.user_timeline('@ARIJIT__SINGH')

with open ('viratKohli.pkl', 'wb') as f:
    pickle.dump(kohli_tweets, f)

with open ('sunilChetri.pkl', 'wb') as f:
    pickle.dump(chetri_tweets, f)
    
with open ('arijit.pkl', 'wb') as f:
    pickle.dump(arijit_tweets, f)
    
print(kohli_tweets)

print(chetri_tweets)

print(arijit_tweets)
# Out:
# [Status(_api=<tweepy.api.API object at 0x000001AD246C7278>, _json={'created_at': 'Mon Jun 17 09:52:44 +0000 2019', 'id': 1140557881411960832, 'id_str': '1140557881411960832', 'text': 'Doing it since the early 90s! 🤓 https://t.co/IVitRHUWpW', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1140557873505697792, 'id_str': '1140557873505697792', 'indices': [32, 55], 'media_url': 'http://pbs.twimg.com/media/D9QTV9AVAAAuWir.jpg', 'media_url_https': 'https://pbs.twimg.com/media/D9QTV9AVAAAuWir.jpg', 'url': 'https://t.co/IVitRHUWpW', 'display_url': 'pic.twitter.com/IVitRHUWpW', 'expanded_url': 'https://twitter.com/imVkohli/status/1140557881411960832/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 571, 'resize': 'fit'}, 'medium': {'w': 1039, 'h': 873, 'resize': 'fit'}, 'large': {'w': 1039, 'h': 873, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1140557873505697792, 'id_str': '1140557873505697792', 'indices': [32, 55], 'media_url': 'http://pbs.twimg.com/media/D9QTV9AVAAAuWir.jpg', 'media_url_https': 'https://pbs.twimg.com/media/D9QTV9AVAAAuWir.jpg', 'url': 'https://t.co/IVitRHUWpW', 'display_url': 'pic.twitter.com/IVitRHUWpW', 'expanded_url': 'https://twitter.com/imVkohli/status/1140557881411960832/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 571, 'resize': 'fit'}, 'medium': {'w': 1039, 'h': 873, 'resize': 'fit'}, 'large': {'w': 1039, 'h': 873, 'resize': 'fit'}}}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 71201743, 'id_str': '71201743', 'name': 'Virat Kohli', 'screen_name': 'imVkohli', 'location': '', 'description': 'The Official twitter account of Virat Kohli, Indian cricketer, gamer, car lover, loves soccer and an enthusiast.', 'url': 'https://t.co/OhSih7EL7w', 'entities': {'url': {'urls': [{'url': 'https://t.co/OhSih7EL7w', 'expanded_url': 'https://instagram.com/virat.kohli', 'display_url': 'instagram.com/virat.kohli', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 29992756, 'friends_count': 51, 'listed_count': 7643, 'created_at': 'Thu Sep 03 07:57:30 +0000 2009', 'favourites_count': 191, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 1757, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '022330', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/789817267567472640/BlpcUEvx_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/789817267567472640/BlpcUEvx_normal.jpg', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'C0DFEC', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'regular'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 16299, 'favorite_count': 202334, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2019, 6, 17, 9, 52, 44), id=1140557881411960832, id_str='1140557881411960832', text='Doing it since the early 90s! 🤓 https://t.co/IVitRHUWpW', truncated=False, entities={'hashtags': [], 'symbols': [], ...
# *******************************
# [Status(_api=<tweepy.api.API object at 0x000001AD246C7278>, _json={'created_at': 'Mon Jun 17 13:49:22 +0000 2019', 'id': 1140617434082054146, 'id_str': '1140617434082054146', 'text': 'Mark your calendars as #Bombers hits your screens on June 22, exclusively on @ZEE5. Really excited to be part of th… https://t.co/9DT73lTudp', 'truncated': True, 'entities': {'hashtags': [{'text': 'Bombers', 'indices': [23, 31]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/9DT73lTudp', 'expanded_url': 'https://twitter.com/i/web/status/1140617434082054146', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 863720408, 'id_str': '863720408', 'name': 'Sunil Chhetri', 'screen_name': 'chetrisunil11', 'location': '', 'description': "My life revolves around shuttling between taking the field for India and Bengaluru FC. Couldn't have had it better. Co-founder GamePlan  https://t.co/bmYGCg4EjN", 'url': None, 'entities': {'description': {'urls': [{'url': 'https://t.co/bmYGCg4EjN', 'expanded_url': 'http://onelink.to/gameplan', 'display_url': 'onelink.to/gameplan', 'indices': [137, 160]}]}}, 'protected': False, 'followers_count': 1563902, 'friends_count': 127, 'listed_count': 312, 'created_at': 'Fri Oct 05 21:46:08 +0000 2012', 'favourites_count': 394, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 2467, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '36807B', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1003302550588645376/vZ2lAjoQ_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1003302550588645376/vZ2lAjoQ_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/863720408/1525839331', 'profile_link_color': '327080', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'EFEFEF', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 14, 'favorite_count': 358, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2019, 6, 17, 13, 49, 22), id=1140617434082054146, id_str='1140617434082054146', text='Mark your calendars as #Bombers hits your screens on June 22, exclusively on @ZEE5. Really excited to be part of th… https://t.co/9DT73lTudp', truncated=True, entities={'hashtags': [{'text': 'Bombers', 'indices': [23, 31]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/9DT73lTudp', 'expanded_url': 'https://twitter.com/i/web/status/1140617434082054146', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x000001AD246C7278>, _json={'id': 863720408, 'id_str': '863720408', 'name': 'Sunil Chhetri', 'screen_name': 'chetrisunil11', 'location': '', 'description': "My life revolves around shuttling between taking the field for India and Bengaluru FC. Couldn't have had it ...
# *******************************
# [Status(_api=<tweepy.api.API object at 0x000001AD246C7278>, _json={'created_at': 'Mon Jun 17 15:40:49 +0000 2019', 'id': 1140645479690096640, 'id_str': '1140645479690096640', 'text': '@iamjbond @KarnikaKohli @free_thinker Kyu aap kyu dhamki de rahe ho ? Aap uske ristedaar ho ?', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'iamjbond', 'name': 'James bond@🙂🙄😎', 'id': 960235258976391169, 'id_str': '960235258976391169', 'indices': [0, 9]}, {'screen_name': 'KarnikaKohli', 'name': 'Karnika', 'id': 219743084, 'id_str': '219743084', 'indices': [10, 23]}, {'screen_name': 'free_thinker', 'name': 'Pratik Sinha', 'id': 7431372, 'id_str': '7431372', 'indices': [24, 37]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1140510703163301889, 'in_reply_to_status_id_str': '1140510703163301889', 'in_reply_to_user_id': 960235258976391169, 'in_reply_to_user_id_str': '960235258976391169', 'in_reply_to_screen_name': 'iamjbond', 'user': {'id': 3119047680, 'id_str': '3119047680', 'name': 'Arijit Singh ™', 'screen_name': 'ARIJIT__SINGH', 'location': 'India', 'description': "Don't Be Confused,Follow Arijit Singh Official Account [ @raiisonai ] Watch Out Every Update Related To Arijit Singh. Views are p(arody)ersonal!", 'url': 'https://t.co/9DxEheZVQq', 'entities': {'url': {'urls': [{'url': 'https://t.co/9DxEheZVQq', 'expanded_url': 'http://facebook.com/arijitsingh', 'display_url': 'facebook.com/arijitsingh', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 44548, 'friends_count': 602, 'listed_count': 18, 'created_at': 'Tue Mar 31 04:16:38 +0000 2015', 'favourites_count': 20172, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 7390, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1114551019629768705/8d3Dit-9_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1114551019629768705/8d3Dit-9_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3119047680/1554564693', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 2, 'favorited': False, 'retweeted': False, 'lang': 'hi'}, created_at=datetime.datetime(2019, 6, 17, 15, 40, 49), id=1140645479690096640, id_str='1140645479690096640', text='@iamjbond @KarnikaKohli @free_thinker Kyu aap kyu dhamki de rahe ho ? Aap uske ristedaar ho ?', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'iamjbond', 'name': 'James bond@🙂🙄😎', 'id': 960235258976391169, 'id_str': '960235258976391169', 'indices': [0, 9]}, {'screen_name': 'KarnikaKohli', 'name': 'Karnika', 'id': 219743084, 'id_str': '219743084', 'indices': [10, 23]}, {'screen_name': 'free_thinker', 'name': 'Pratik Sinha', 'id': 7431372, 'id_str': '7431372', 'indices': [24, 37]}], 'urls': []}, source='Twitter for Android', source_url='http://twitter.com/download/android', in_reply_to_status_id=1140510703163301889, in_reply_to_status_id_str='1140510703163301889', in_reply_to_user_id=960235258976391169, in_reply_to_user_id_str='960235258976391169', in_repl ...
